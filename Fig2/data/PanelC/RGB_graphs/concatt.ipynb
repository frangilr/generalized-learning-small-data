# %%
import pandas as pd
import os

# %%
cats = ["bottle", "bowl", "cup", "door", "window", "chair", "table", "spoon"]
dfs = []
subjs = ["030FD", "031HW", "032SR", "033SE", "036MR", "037SM", "038RB", "039ED", "041EC",
          "042MB", "043MP", "045NA", "046TE", "047MS"]
for cat in cats:
    for subj in subjs:
        # /u/fraramir/me/STS_journal_submission/STS_github_release/Fig2/data/PanelC/RGB_graphs/subs/label_shuffling_graphs_null_RGB_10pct_030FD_bottle.csv
        temp_df = pd.read_csv(f"subs/edge_shuffling_graphs_null_RGB_10pct_{subj}_{cat}.csv")
        dfs.append(temp_df)
        del temp_df

df = pd.concat(dfs, ignore_index=True)
print(df.shape)
# Out:
# (112, 5)

# %%
df.to_csv(f"edge_shuffling_graphs_null_RGB_10pct.csv", index=False)
